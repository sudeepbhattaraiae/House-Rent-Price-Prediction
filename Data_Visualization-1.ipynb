# 8   https://images.craigslist.org/00W0W_aMt5LvqkQh...
# 9   https://images.craigslist.org/01313_8AoC9NJZWA...
# 10  https://images.craigslist.org/00O0O_5wWo0TwRHn...
# 11  https://images.craigslist.org/00303_6CDk4x4o7i...
# 12  https://images.craigslist.org/00W0W_4YPd2WkE4U...
# 13  https://images.craigslist.org/00z0z_57Ct5yuqbJ...
# 14  https://images.craigslist.org/00F0F_1U5yCEgpCC...
# 15  https://images.craigslist.org/00z0z_4zB7LuIg63...
# 16  https://images.craigslist.org/01616_daghmBUvTC...
# 17  https://images.craigslist.org/01212_hHbChrx2vM...
# 18  https://images.craigslist.org/00m0m_2NL19adjhn...
# 19  https://images.craigslist.org/00e0e_2EXJaNgIMh...
#
#                                           description      lat     long  state
# 0   Ridgeview by Vintage is where you will find al...  39.5483 -119.796     ca
# 1   Conveniently located in the middle town of Ren...  39.5026 -119.789     ca
# 2   2BD | 2BA | 1683SQFTDiscover exceptional servi...  39.6269 -119.708     ca
# 3   MOVE IN SPECIAL FREE WASHER/DRYER WITH 6 OR 12...  39.4477 -119.771     ca
# 4   Move In Today: Reno Low-Cost, Clean & Furnishe...  39.5357 -119.805     ca
# 5   1BD | 1BA | 720SQFTIn addition to attractive, ...  39.4572 -119.776     ca
# 6   Tucked away in a park-like setting on the edge...  39.5118 -119.802     ca
# 7   MOVE IN SPECIAL FREE WASHER/DRYER WITH 6 OR 12...  39.4477 -119.771     ca
# 8   BRAND NEW APARTMENT HOMES, NOW OPEN!  **GET 1 ...  39.6185 -119.672     ca
# 9   6850 Sharlands Ave E-1021 Reno NV 89523       ...  39.5193 -119.897     ca
# 10  In addition to attractive, comfortable apartme...  39.4572 -119.776     ca
# 11  2741 Albazano Drive Sparks, NV 89436          ...  39.5987 -119.693     ca
# 12  Welcome Home to Zephyr Pointe Apartments   Thi...  39.5384 -119.863     ca
# 13  Style, substance, and sustainability are the p...  39.5393 -119.750     ca
# 14  Pre-leasing for 2020! Winter Special - 6 Weeks...  39.5502 -119.718     ca
# 15  200 Talus Way #221 Reno, NV 89523             ...  39.5617 -119.828     ca
# 16  Ridgeview by Vintage is where you will find al...  39.5483 -119.796     ca
# 17  Inova14001 SUMMIT SIERRA BLVDReno, NV 89511Tak...  39.4015 -119.755     ca
# 18  12001 Andes Street Reno, NV 89506             ...  39.6369 -119.880     ca
# 19  3 YEAR NEW EXECUTIVE LENNAR HOME: 3 bedroom, 2...  39.5614 -119.695     ca
#
# [20 rows x 22 columns]

# %%
#retrieve the column names of the DataFrame.
house.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'type', 'sqfeet', 'beds',
#        'baths', 'cats_allowed', 'dogs_allowed', 'smoking_allowed',
#        'wheelchair_access', 'electric_vehicle_charge', 'comes_furnished',
#        'laundry_options', 'parking_options', 'image_url', 'description', 'lat',
#        'long', 'state'],
#       dtype='object')

# %%
#display concise summary information about the DataFrame.
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384977 entries, 0 to 384976
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       384977 non-null  int64
#  1   url                      384977 non-null  object
#  2   region                   384977 non-null  object
#  3   region_url               384977 non-null  object
#  4   price                    384977 non-null  int64
#  5   type                     384977 non-null  object
#  6   sqfeet                   384977 non-null  int64
#  7   beds                     384977 non-null  int64
#  8   baths                    384977 non-null  float64
#  9   cats_allowed             384977 non-null  int64
#  10  dogs_allowed             384977 non-null  int64
#  11  smoking_allowed          384977 non-null  int64
#  12  wheelchair_access        384977 non-null  int64
#  13  electric_vehicle_charge  384977 non-null  int64
#  14  comes_furnished          384977 non-null  int64
#  15  laundry_options          305951 non-null  object
#  16  parking_options          244290 non-null  object
#  17  image_url                384977 non-null  object
#  18  description              384975 non-null  object
#  19  lat                      383059 non-null  float64
#  20  long                     383059 non-null  float64
#  21  state                    384977 non-null  object
# dtypes: float64(3), int64(10), object(9)
# memory usage: 64.6+ MB

# %%
#generate descriptive statistics for the DataFrame.
house.describe()
# Out:
#                  id         price        sqfeet           beds          baths  \
# count  3.849770e+05  3.849770e+05  3.849770e+05  384977.000000  384977.000000
# mean   7.040982e+09  8.825722e+03  1.059900e+03       1.905345       1.480718
# std    8.800376e+06  4.462200e+06  1.915076e+04       3.494572       0.618061
# min    7.003808e+09  0.000000e+00  0.000000e+00       0.000000       0.000000
# 25%    7.035979e+09  8.050000e+02  7.500000e+02       1.000000       1.000000
# 50%    7.043320e+09  1.036000e+03  9.490000e+02       2.000000       1.000000
# 75%    7.048426e+09  1.395000e+03  1.150000e+03       2.000000       2.000000
# max    7.051292e+09  2.768307e+09  8.388607e+06    1100.000000      75.000000
#
#         cats_allowed   dogs_allowed  smoking_allowed  wheelchair_access  \
# count  384977.000000  384977.000000    384977.000000      384977.000000
# mean        0.726890       0.707918         0.731771           0.082111
# std         0.445557       0.454721         0.443038           0.274535
# min         0.000000       0.000000         0.000000           0.000000
# 25%         0.000000       0.000000         0.000000           0.000000
# 50%         1.000000       1.000000         1.000000           0.000000
# 75%         1.000000       1.000000         1.000000           0.000000
# max         1.000000       1.000000         1.000000           1.000000
#
#        electric_vehicle_charge  comes_furnished            lat           long
# count            384977.000000    384977.000000  383059.000000  383059.000000
# mean                  0.012871         0.048128      37.233487     -92.700631
# std                   0.112718         0.214036       5.546171      16.531980
# min                   0.000000         0.000000     -43.533300    -163.894000
# 25%                   0.000000         0.000000      33.454700    -100.775000
# 50%                   0.000000         0.000000      37.647800     -87.745100
# 75%                   0.000000         0.000000      41.138300     -81.179600
# max                   1.000000         1.000000     102.036000     172.633000

# %% [raw]
# The significant difference between the mean and standard deviation indicates high variability in the data. Extreme minimum and maximum values for square footage, bedrooms, bathrooms, and price suggest the presence of outliers.

# %%
#retrieve the dimensions of the DataFrame.
house.shape
# Out:
# (384977, 22)

# %%
#check for null values in the DataFrame.
house.isnull()
# Out:
#            id    url  region  region_url  price   type  sqfeet   beds  baths  \
# 0       False  False   False       False  False  False   False  False  False
# 1       False  False   False       False  False  False   False  False  False
# 2       False  False   False       False  False  False   False  False  False
# 3       False  False   False       False  False  False   False  False  False
# 4       False  False   False       False  False  False   False  False  False
# ...       ...    ...     ...         ...    ...    ...     ...    ...    ...
# 384972  False  False   False       False  False  False   False  False  False
# 384973  False  False   False       False  False  False   False  False  False
# 384974  False  False   False       False  False  False   False  False  False
# 384975  False  False   False       False  False  False   False  False  False
# 384976  False  False   False       False  False  False   False  False  False
#
#         cats_allowed  ...  wheelchair_access  electric_vehicle_charge  \
# 0              False  ...              False                    False
# 1              False  ...              False                    False
# 2              False  ...              False                    False
# 3              False  ...              False                    False
# 4              False  ...              False                    False
# ...              ...  ...                ...                      ...
# 384972         False  ...              False                    False
# 384973         False  ...              False                    False
# 384974         False  ...              False                    False
# 384975         False  ...              False                    False
# 384976         False  ...              False                    False
#
#         comes_furnished  laundry_options  parking_options  image_url  \
# 0                 False            False            False      False
# 1                 False            False            False      False
# 2                 False            False            False      False
# 3                 False            False            False      False
# 4                 False            False             True      False
# ...                 ...              ...              ...        ...
# 384972            False            False            False      False
# 384973            False            False             True      False
# 384974            False            False            False      False
# 384975            False            False            False      False
# 384976            False            False            False      False
#
#         description    lat   long  state
# 0             False  False  False  False
# 1             False  False  False  False
# 2             False  False  False  False
# 3             False  False  False  False
# 4             False  False  False  False
# ...             ...    ...    ...    ...
# 384972        False  False  False  False
# 384973        False  False  False  False
# 384974        False  False  False  False
# 384975        False  False  False  False
# 384976        False  False  False  False
#
# [384977 rows x 22 columns]

# %%
#display the data types of each column in the DataFrame.
house.dtypes
# Out:
# id                           int64
# url                         object
# region                      object
# region_url                  object
# price                        int64
# type                        object
# sqfeet                       int64
# beds                         int64
# baths                      float64
# cats_allowed                 int64
# dogs_allowed                 int64
# smoking_allowed              int64
# wheelchair_access            int64
# electric_vehicle_charge      int64
# comes_furnished              int64
# laundry_options             object
# parking_options             object
# image_url                   object
# description                 object
# lat                        float64
# long                       float64
# state                       object
# dtype: object

# %%
#count the number of null values in each column of the DataFrame.
house.isnull().sum()
# Out:
# id                              0
# url                             0
# region                          0
# region_url                      0
# price                           0
# type                            0
# sqfeet                          0
# beds                            0
# baths                           0
# cats_allowed                    0
# dogs_allowed                    0
# smoking_allowed                 0
# wheelchair_access               0
# electric_vehicle_charge         0
# comes_furnished                 0
# laundry_options             79026
# parking_options            140687
# image_url                       0
# description                     2
# lat                          1918
# long                         1918
# state                           0
# dtype: int64

# %%
#generate rounded descriptive statistics for the DataFrame 'house' and transpose the result.
house.describe().round(2).T
# Out:
#                             count          mean         std           min  \
# id                       384977.0  7.040982e+09  8800376.31  7.003808e+09
# price                    384977.0  8.825720e+03  4462199.88  0.000000e+00
# sqfeet                   384977.0  1.059900e+03    19150.76  0.000000e+00
# beds                     384977.0  1.910000e+00        3.49  0.000000e+00
# baths                    384977.0  1.480000e+00        0.62  0.000000e+00
# cats_allowed             384977.0  7.300000e-01        0.45  0.000000e+00
# dogs_allowed             384977.0  7.100000e-01        0.45  0.000000e+00
# smoking_allowed          384977.0  7.300000e-01        0.44  0.000000e+00
# wheelchair_access        384977.0  8.000000e-02        0.27  0.000000e+00
# electric_vehicle_charge  384977.0  1.000000e-02        0.11  0.000000e+00
# comes_furnished          384977.0  5.000000e-02        0.21  0.000000e+00
# lat                      383059.0  3.723000e+01        5.55 -4.353000e+01
# long                     383059.0 -9.270000e+01       16.53 -1.638900e+02
#
#                                   25%           50%           75%  \
# id                       7.035979e+09  7.043320e+09  7.048426e+09
# price                    8.050000e+02  1.036000e+03  1.395000e+03
# sqfeet                   7.500000e+02  9.490000e+02  1.150000e+03
# beds                     1.000000e+00  2.000000e+00  2.000000e+00
# baths                    1.000000e+00  1.000000e+00  2.000000e+00
# cats_allowed             0.000000e+00  1.000000e+00  1.000000e+00
# dogs_allowed             0.000000e+00  1.000000e+00  1.000000e+00
# smoking_allowed          0.000000e+00  1.000000e+00  1.000000e+00
# wheelchair_access        0.000000e+00  0.000000e+00  0.000000e+00
# electric_vehicle_charge  0.000000e+00  0.000000e+00  0.000000e+00
# comes_furnished          0.000000e+00  0.000000e+00  0.000000e+00
# lat                      3.345000e+01  3.765000e+01  4.114000e+01
# long                    -1.007800e+02 -8.775000e+01 -8.118000e+01
#
#                                   max
# id                       7.051292e+09
# price                    2.768307e+09
# sqfeet                   8.388607e+06
# beds                     1.100000e+03
# baths                    7.500000e+01
# cats_allowed             1.000000e+00
# dogs_allowed             1.000000e+00
# smoking_allowed          1.000000e+00
# wheelchair_access        1.000000e+00
# electric_vehicle_charge  1.000000e+00
# comes_furnished          1.000000e+00
# lat                      1.020400e+02
# long                     1.726300e+02

# %% [raw]
# The dataset comprises housing data across various regions, encompassing details like size, type, square footage, price, and bed count, necessitating cleaning to suit specific requirements. Upon examining inter-variable relationships, informed conclusions can guide potential buyers towards profitable decisions.

# %% [markdown]
# #### Steps for Data Cleaning
#
# * Pick those columns that are relevant for the analysis and drop those that are not.
# * Check for any null values
# * Fill or drop the records with null values
# * Find the percentage of the null records
# * Filter the records according to the occurence

# %%
#Getting the percentage of the null records
null_values=pd.DataFrame(house.isnull().sum(),columns=['null_sum'])
null_values=null_values[null_values.null_sum>0]
null_values['percentage']=(null_values.null_sum/len(house ))*100
null_values=null_values.sort_values(by='percentage',ascending=False)
null_values
# Out:
#                  null_sum  percentage
# parking_options    140687   36.544261
# laundry_options     79026   20.527460
# lat                  1918    0.498212
# long                 1918    0.498212
# description             2    0.000520

# %% [raw]
# Before imputing null values, it's prudent to eliminate irrelevant features that do not contribute to estimating house rent. We will drop the columns 'url', 'id', 'image_url', 'description', and 'region_url' as they are not highly relevant for our analysis.

# %%
house.drop(columns=['url','id','image_url','description','region_url'],inplace=True)

# %%
house.shape
# Out:
# (384977, 17)

# %%
# Cleaning the region variable based on a forward slash ("/")
def region_forward_slash(x):
    if isinstance(x, str):
        tokens = x.split('/')
        return tokens[0].strip()
    else:
        return x  # Return the value as is if it's not a string (NaN)

house['region'] = house['region'].apply(region_forward_slash)

# %%
def strip_last_two_uppercase_chars(string):
    if string is not None and len(string) >= 2 and string[-2:].isupper():
        return string[:-2].strip()
    elif string is not None:
        return string.strip()  # Adjusted to strip trailing whitespaces
    else:
        return string

# %%
house.region.unique()
# Out:
# array(['reno', 'sacramento', 'boulder', 'visalia-tulare', 'santa barbara',
#        'SF bay area', 'siskiyou county', 'ventura county', 'san diego',
#        'san luis obispo', 'stockton', 'santa maria', 'susanville',
#        'colorado springs', 'yuba-sutter', 'denver', 'northwest CT',
#        'fort collins', 'western slope', 'eastern CT', 'hartford',
#        'new haven', 'washington, DC', 'high rockies', 'pueblo',
#        'daytona beach', 'ft myers', 'gainesville', 'jacksonville',
#        'ocala', 'eastern CO', 'heartland florida', 'delaware', 'lakeland',
#        'florida keys', 'north central FL', 'orlando', 'panama city',
#        'pensacola', 'sarasota-bradenton', 'south florida', 'okaloosa',
#        'space coast', 'tallahassee', 'tampa bay area', 'atlanta',
#        'augusta', 'brunswick', 'athens', 'treasure coast', 'albany',
#        'st augustine', 'macon', 'columbus', 'northwest GA', 'savannah',
#        'hawaii', 'boise', 'east idaho', 'statesboro', 'spokane',
#        'valdosta', 'bloomington-normal', 'champaign urbana', 'chicago',
#        'twin falls', 'decatur', 'la salle co', 'quad cities, IA',
#        'st louis, MO', 'peoria', 'evansville', 'springfield',
#        'bloomington', 'lewiston', 'pullman', 'indianapolis', 'fort wayne',
#        'rockford', 'south bend', 'ames', 'richmond', 'southern illinois',
#        'mattoon-charleston', 'muncie', 'western IL', 'lafayette',
#        'kokomo', 'terre haute', 'cedar rapids', 'des moines', 'omaha',
#        'wichita', 'fort dodge', 'lawrence', 'salina', 'sioux city',
#        'bowling green', 'lexington', 'eastern kentucky', 'iowa city',
#        'louisville', 'dubuque', 'baton rouge', 'waterloo', 'manhattan',
#        'western KY', 'topeka', 'monroe', 'mason city', 'new orleans',
#        'kansas city, MO', 'southeast IA', 'lake charles', 'southeast KS',
#        'huntington-ashland', 'northwest KS', 'southwest KS', 'shreveport',
#        'central louisiana', 'houma', 'owensboro', 'maine', 'lansing',
#        'annapolis', 'baltimore', 'frederick', 'southern maryland',
#        'boston', 'south coast', 'western massachusetts', 'worcester',
#        'western maryland', 'ann arbor', 'battle creek', 'detroit metro',
#        'holland', 'cumberland valley', 'flint', 'kalamazoo', 'muskegon',
#        'saginaw-midland-baycity', 'upper peninsula', 'eastern shore',
#        'cape cod', 'grand rapids', 'bemidji', 'central michigan',
#        'northern michigan', 'jackson', 'southwest michigan', 'the thumb',
#        'port huron', 'brainerd', 'duluth', 'fargo', 'minneapolis',
#        'rochester', 'gulfport', 'st cloud', 'hattiesburg', 'asheville',
#        'north mississippi', 'joplin', 'kirksville', 'mankato',
#        'southwest MS', 'columbia', 'southwest MN', 'st joseph',
#        'charlotte', 'boone', 'billings', 'missoula', 'fayetteville',
#        'eastern NC', 'greensboro', 'raleigh', 'hickory',
#        'lake of the ozarks', 'meridian', 'southeast missouri',
#        'kansas city', 'st louis', 'bozeman', 'eastern montana',
#        'kalispell', 'great falls', 'helena', 'butte', 'outer banks',
#        'wilmington', 'winston-salem', 'lincoln', 'las vegas',
#        'north platte', 'central NJ', 'north jersey', 'jersey shore',
#        'south jersey', 'albuquerque', 'buffalo', 'ithaca', 'farmington',
#        'long island', 'hudson valley', 'syracuse',
#        'plattsburgh-adirondacks', 'catskills', 'watertown',
#        'grand island', 'santa fe', 'scottsbluff', 'new york city',
#        'binghamton', 'utica-rome-oneida', 'new hampshire', 'elko',
#        'clovis', 'finger lakes', 'chautauqua', 'elmira-corning',
#        'las cruces', 'roswell', 'glens falls', 'potsdam-canton-massena',
#        'oneonta', 'twin tiers NY', 'cincinnati', 'north dakota', 'akron',
#        'bismarck', 'grand forks', 'dayton', 'cleveland', 'lima', 'toledo',
#        'northern panhandle', 'oklahoma city', 'zanesville', 'ashtabula',
#        'lawton', 'chillicothe', 'texoma', 'tulsa', 'bend', 'corvallis',
#        'tuscarawas co', 'east oregon', 'eugene', 'medford-ashland',
#        'oregon coast', 'portland', 'mansfield', 'stillwater',
#        'parkersburg-marietta', 'northwest OK', 'sandusky', 'youngstown',
#        'fort smith, AR', 'klamath falls', 'salem', 'roseburg',
#        'harrisburg', 'philadelphia', 'erie', 'pittsburgh',
#        'lehigh valley', 'rhode island', 'scranton', 'altoona-johnstown',
#        'reading', 'charleston', 'williamsport', 'lancaster',
#        'state college', 'greenville', 'myrtle beach', 'hilton head',
#        'chattanooga', 'poconos', 'clarksville', 'meadville',
#        'south dakota', 'cookeville', 'york', 'sioux falls', 'florence',
#        'northeast SD', 'rapid city', 'pierre', 'knoxville', 'memphis',
#        'nashville', 'amarillo', 'austin', 'college station', 'lubbock',
#        'dallas', 'abilene', 'el paso', 'corpus christi', 'del rio',
#        'galveston', 'houston', 'killeen', 'laredo', 'mcallen',
#        'tri-cities', 'brownsville', 'beaumont', 'deep east texas',
#        'odessa', 'waco', 'san antonio', 'san angelo', 'san marcos',
#        'tyler', 'victoria', 'wichita falls', 'provo', 'ogden-clearfield',
#        'salt lake city', 'fredericksburg', 'charlottesville', 'lynchburg',
#        'norfolk', 'roanoke', 'winchester', 'texarkana', 'southwest TX',
#        'vermont', 'logan', 'st george', 'danville', 'harrisonburg',
#        'new river valley', 'southwest VA', 'bellingham',
#        'kennewick-pasco-richland', 'seattle-tacoma', 'moses lake',
#        'olympic peninsula', 'yakima', 'morgantown', 'madison',
#        'wenatchee', 'skagit', 'milwaukee', 'west virginia (old)',
#        'wausau', 'janesville', 'kenosha-racine', 'eastern panhandle',
#        'southern WV', 'green bay', 'la crosse', 'wyoming',
#        'appleton-oshkosh-FDL', 'eau claire', 'sheboygan', 'northern WI',
#        'auburn', 'birmingham', 'phoenix', 'gadsden-anniston',
#        'huntsville', 'dothan', 'mobile', 'montgomery', 'tuscaloosa',
#        'anchorage', 'fairbanks', 'flagstaff', 'tucson', 'little rock',
#        'prescott', 'yuma', 'bakersfield', 'fresno', 'hanford-corcoran',
#        'humboldt county', 'inland empire', 'los angeles',
#        'kenai peninsula', 'southeast alaska', 'mohave county',
#        'fort smith', 'jonesboro', 'show low', 'gold country',
#        'sierra vista', 'chico', 'imperial county', 'modesto',
#        'orange county', 'mendocino county', 'merced', 'palm springs',
#        'monterey bay', 'redding'], dtype=object)

# %%
house.shape
# Out:
# (384977, 17)

# %% [raw]
# The most crucial features for rental price estimation include square footage, region, type, number of bedrooms, and number of bathrooms. While other features may have less significance individually, they collectively contribute to the estimation process and should be considered as well.

# %%
#retrieve unique values of the 'parking_options' column in the DataFrame.
house.parking_options.unique()
# Out:
# array(['carport', 'attached garage', nan, 'off-street parking',
#        'detached garage', 'street parking', 'no parking', 'valet parking'],
#       dtype=object)

# %%
#fill missing values in the 'parking_options' column of the DataFrame 'house' with 'No parking'.
house.parking_options.fillna('No parking', inplace = True)

# %% [markdown]
# #### Features engineering

# %%
#fill missing values in 'cats_allowed' and 'dogs_allowed' columns with 0
house['cats_allowed'].fillna(0, inplace=True)
house['dogs_allowed'].fillna(0, inplace=True)

#convert 'cats_allowed' and 'dogs_allowed' columns to integers
house['cats_allowed'] = house['cats_allowed'].astype(int)
house['dogs_allowed'] = house['dogs_allowed'].astype(int)

#create a new column 'pets_allowed' in the pandas DataFrame 'house' that takes the value 1 if both 'cats_allowed' and 'dogs_allowed' are 1.
house['pets_allowed'] = (house['cats_allowed'] & house['dogs_allowed'])

# Drop the 'cats_allowed' and 'dogs_allowed' columns from the DataFrame
house.drop(['cats_allowed', 'dogs_allowed'], axis='columns', inplace=True)

# %%
house.columns
# Out:
# Index(['region', 'price', 'type', 'sqfeet', 'beds', 'baths', 'smoking_allowed',
#        'wheelchair_access', 'electric_vehicle_charge', 'comes_furnished',
#        'laundry_options', 'parking_options', 'lat', 'long', 'state',
#        'pets_allowed'],
#       dtype='object')

# %%
#count the occurrences of each unique value in the 'laundry_options' column.
house.laundry_options.value_counts()
# Out:
# laundry_options
# w/d in unit           131783
# w/d hookups            75568
# laundry on site        58873
# laundry in bldg        36103
# no laundry on site      3624
# Name: count, dtype: int64

# %%
#fill missing values in the 'laundry_options' column with 'Not Available' to denote properties without specified laundry options.
house['laundry_options'] = house['laundry_options'].fillna('Not Available')

# %%
house.laundry_options.value_counts()
# Out:
# laundry_options
# w/d in unit           131783
# Not Available          79026
# w/d hookups            75568
# laundry on site        58873
# laundry in bldg        36103
# no laundry on site      3624
# Name: count, dtype: int64

# %% [markdown]
# #### Removing Outliers

# %%
#checking how many values present
house.baths.value_counts()
# Out:
# baths
# 1.0     198184
# 2.0     134649
# 1.5      27363
# 2.5      13162
# 3.0       5549
# 0.0       3107
# 4.0       1495
# 3.5       1007
# 4.5        231
# 5.0        131
# 5.5         57
# 6.0         26
# 7.0          4
# 6.5          4
# 75.0         2
# 7.5          2
# 8.5          1
# 35.0         1
# 8.0          1
# 25.0         1
# Name: count, dtype: int64

# %%
#drop rows with non-finite values in the 'baths' column
house = house.dropna(subset=['baths'])

#convert the values in the 'baths' column from float to integer data type
house["baths"] = house["baths"].astype(int)

# %%
#checking how many values present
house.beds.value_counts()
# Out:
# beds
# 2       175513
# 1       117226
# 3        67037
# 4        11575
# 0        10978
# 5         2324
# 6          240
# 7           49
# 8           31
# 1000         2
# 1100         2
# Name: count, dtype: int64

# %%
house
# Out:
#        region  price       type  sqfeet  beds  baths  smoking_allowed  \
# 0        reno   1148  apartment    1078     3      2                0
# 1        reno   1200      condo    1001     2      2                0
# 2        reno   1813  apartment    1683     2      2                1
# 3        reno   1095  apartment     708     1      1                1
# 4        reno    289  apartment     250     0      1                1
# ...       ...    ...        ...     ...   ...    ...              ...
# 384972   reno   1295  apartment     957     2      2                1
# 384973   reno   1549  apartment    1034     2      2                0
# 384974   reno   1249  apartment     840     2      1                1
# 384975   reno   1429  apartment     976     2      2                1
# 384976   reno   1295  apartment     957     2      2                1
#
#         wheelchair_access  electric_vehicle_charge  comes_furnished  \
# 0                       0                        0                0
# 1                       0                        0                0
# 2                       0                        0                0
# 3                       0                        0                0
# 4                       1                        0                1
# ...                   ...                      ...              ...
# 384972                  0                        0                0
# 384973                  0                        0                0
# 384974                  0                        0                0
# 384975                  0                        0                0
# 384976                  0                        0                0
#
#         laundry_options     parking_options      lat     long state  \
# 0           w/d in unit             carport  39.5483 -119.796    ca
# 1           w/d hookups             carport  39.5026 -119.789    ca
# 2           w/d in unit     attached garage  39.6269 -119.708    ca
# 3           w/d in unit             carport  39.4477 -119.771    ca
# 4       laundry on site          No parking  39.5357 -119.805    ca
# ...                 ...                 ...      ...      ...   ...
# 384972      w/d in unit             carport  39.4477 -119.771    ca
# 384973      w/d in unit          No parking  39.6269 -119.708    ca
# 384974  laundry on site  off-street parking  39.5358 -119.746    ca
# 384975      w/d in unit             carport  39.5585 -119.703    ca
# 384976      w/d in unit             carport  39.4477 -119.771    ca
#
#         pets_allowed
# 0                  1
# 1                  0
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 384972             1
# 384973             1
# 384974             1
# 384975             1
# 384976             1
#
# [384977 rows x 16 columns]

# %% [raw]
# To ensure normal range, filter out entries with more than 4 bedrooms and bathrooms, as they are considered beyond standard limits for a house.

# %%
outlier1 = ((house["beds"]>4) | (house["baths"]>4))
print("There is {} outlier".format(house[outlier1]["beds"].count()))
# Out:
# There is 2705 outlier

# %%
house = house[~outlier1]

# %%
house.shape
# Out:
# (382272, 16)

# %% [raw]
# To comply with zoning regulations, eliminate entries with square footage below 120 or above 5000, as it ensures adherence to minimum and maximum limits. Additionally, filter out rental prices exceeding $10,000, as it suggests potential homeownership rather than rental affordability.

# %%
outlier2 = ((house["sqfeet"]<120) | (house["sqfeet"]>5000) | (house["price"]<100) | (house["price"]>10000))
print("There is {} outlier".format(house[outlier2]["pets_allowed"].count()))
# Out:
# There is 3564 outlier

# %%
house = house[~outlier2]

# %%
house.shape
# Out:
# (378708, 16)

# %% [markdown]
# #### Dimensionality reduction

# %%
#count the occurrences of each unique value in the 'type' column of the DataFrame 'house'.
house.type.value_counts()
# Out:
# type
# apartment          315010
# house               30969
# townhouse           15626
# condo                5946
# duplex               4950
# manufactured         4099
# cottage/cabin         725
# loft                  687
# flat                  521
# in-law                169
# land                    5
# assisted living         1
# Name: count, dtype: int64

# %% [raw]
# We will filter the DataFrame to consider only those records where the type of the house has been listed more than 200 times.

# %%
new_type=['apartment', 'condo', 'house', 'duplex', 'townhouse']
house=house.loc[house.type.isin(new_type)]

# %%
house.type.value_counts()
# Out:
# type
# apartment    315010
# house         30969
# townhouse     15626
# condo          5946
# duplex         4950
# Name: count, dtype: int64

# %% [raw]
# Let's fill in the missing values with appropriate measures of central tendency. For numerical columns, we'll use the mean.

# %%
house['lat'] = house['lat'].fillna(house['lat'].mean())
house['long'] = house['long'].fillna(house['long'].mean())

# %%
house
# Out:
#        region  price       type  sqfeet  beds  baths  smoking_allowed  \
# 0        reno   1148  apartment    1078     3      2                0
# 1        reno   1200      condo    1001     2      2                0
# 2        reno   1813  apartment    1683     2      2                1
# 3        reno   1095  apartment     708     1      1                1
# 4        reno    289  apartment     250     0      1                1
# ...       ...    ...        ...     ...   ...    ...              ...
# 384972   reno   1295  apartment     957     2      2                1
# 384973   reno   1549  apartment    1034     2      2                0
# 384974   reno   1249  apartment     840     2      1                1
# 384975   reno   1429  apartment     976     2      2                1
# 384976   reno   1295  apartment     957     2      2                1
#
#         wheelchair_access  electric_vehicle_charge  comes_furnished  \
# 0                       0                        0                0
# 1                       0                        0                0
# 2                       0                        0                0
# 3                       0                        0                0
# 4                       1                        0                1
# ...                   ...                      ...              ...
# 384972                  0                        0                0
# 384973                  0                        0                0
# 384974                  0                        0                0
# 384975                  0                        0                0
# 384976                  0                        0                0
#
#         laundry_options     parking_options      lat     long state  \
# 0           w/d in unit             carport  39.5483 -119.796    ca
# 1           w/d hookups             carport  39.5026 -119.789    ca
# 2           w/d in unit     attached garage  39.6269 -119.708    ca
# 3           w/d in unit             carport  39.4477 -119.771    ca
# 4       laundry on site          No parking  39.5357 -119.805    ca
# ...                 ...                 ...      ...      ...   ...
# 384972      w/d in unit             carport  39.4477 -119.771    ca
# 384973      w/d in unit          No parking  39.6269 -119.708    ca
# 384974  laundry on site  off-street parking  39.5358 -119.746    ca
# 384975      w/d in unit             carport  39.5585 -119.703    ca
# 384976      w/d in unit             carport  39.4477 -119.771    ca
#
#         pets_allowed
# 0                  1
# 1                  0
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 384972             1
# 384973             1
# 384974             1
# 384975             1
# 384976             1
#
# [372501 rows x 16 columns]

# %%
house.isnull().sum()
# Out:
# region                     0
# price                      0
# type                       0
# sqfeet                     0
# beds                       0
# baths                      0
# smoking_allowed            0
# wheelchair_access          0
# electric_vehicle_charge    0
# comes_furnished            0
# laundry_options            0
# parking_options            0
# lat                        0
# long                       0
# state                      0
# pets_allowed               0
# dtype: int64

# %%
#create a subset DataFrame containing specific columns
house_opt = house[['smoking_allowed', 'wheelchair_access', 'electric_vehicle_charge', 'comes_furnished']]

# %%
house_opt
# Out:
#         smoking_allowed  wheelchair_access  electric_vehicle_charge  \
# 0                     0                  0                        0
# 1                     0                  0                        0
# 2                     1                  0                        0
# 3                     1                  0                        0
# 4                     1                  1                        0
# ...                 ...                ...                      ...
# 384972                1                  0                        0
# 384973                0                  0                        0
# 384974                1                  0                        0
# 384975                1                  0                        0
# 384976                1                  0                        0
#
#         comes_furnished
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     1
# ...                 ...
# 384972                0
# 384973                0
# 384974                0
# 384975                0
# 384976                0
#
# [372501 rows x 4 columns]

# %%
house['smoking_allowed'].unique()
# Out:
# array([0, 1])

# %%
house['wheelchair_access'].unique()
# Out:
# array([0, 1])

# %%
house['electric_vehicle_charge'].unique()
# Out:
# array([0, 1])

# %%
house['comes_furnished'].unique()
# Out:
# array([0, 1])

# %% [raw]
# These columns can be utilized for visualization and further analysis by converting them into boolean values.

# %% [markdown]
# ### DATA VISUALIZATION

# %%
# Importing matplotlib for plotting
import matplotlib.pyplot as plt

# Importing seaborn for color palettes and styles
import seaborn as sns

# %%
# Generate a color palette based on the number of unique values in 'type' column
colors = sns.color_palette('pastel', len(house['type'].unique()))

# Plot pie chart
house['type'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05, 0.05],autopct='%1.1f%%', colors=colors, shadow=True, figsize=(10, 8))

# Add legend with unique types
plt.legend(house['type'].unique(), loc="best")

# Add title
plt.title('Exploring the Diversity of House Types', fontsize=18)

# Show plot
plt.show()

# %% [markdown]
# The pie chart illustrates the diversity of house types based on the distribution of listings. Apartment properties dominate the listings,
# followed by house, townhouses, condo, and duplex at least. This visualization provides a comprehensive overview of the types of properties
# available in the housing market, facilitating better understanding and decision-making for buyers.

# %%
import warnings
warnings.filterwarnings("ignore")

# Set a light colorful palette
colors = sns.color_palette('pastel')

# Create the bar plot using seaborn
sns.barplot(x=house["type"], y=house["price"], palette=colors)

# Set figure size
fig = plt.gcf()
fig.set_size_inches(15, 10)

# Add horizontal grid lines
plt.grid(axis='y', linestyle='--', alpha=0.2)

# Add title and labels
plt.title('Exploring Price Distribution Across Different House Types',fontsize=18)
plt.xlabel('House Type',fontsize=14)
plt.ylabel('Price in USD',fontsize=14)

# Add legend with unique types
plt.legend(house['type'].unique(), loc="upper right")

# Show the plot
plt.show()

# %% [markdown]
# The visualization depicts the distribution of house prices across different types, showcasing variations in pricing trends where the condos
# and houses are pricey whereas apartments are cheaper comparitively.The bar plot offers a clear comparison of price ranges for various house
# types.This summary aids in understanding the relationship between house types and their respective price distributions, facilitating informed decisions in the real estate market.

# %%
# Create a figure and axis object with a specified size
fig, ax = plt.subplots(figsize=(16, 16))

# Group the data by square footage and calculate the mean price, then apply a rolling mean with window size 25
grouped = house.groupby("sqfeet")["price"].mean()
rollingGrouped = grouped.rolling(25).mean()

# Extract square footage and price data from the rolling mean
sqfeetData = rollingGrouped.index.values
priceData = rollingGrouped.values

# Set the title and labels for the plot
ax.set_title('Price per Square Footage', fontsize=18)
ax.set_xlabel("Square Footage", fontsize=14)
ax.set_ylabel("Price", fontsize=14)

# Plot the data as a line graph
ax.plot(sqfeetData, priceData)

ax.grid(axis='y', linestyle='--', alpha=0.1)

# Show the plot
plt.show()

# %% [markdown]
# The line graph illustrates the average price per square footage. As square footage increases, the price generally tends to rise, indicating a
# positive correlation between these two variables.

# %%
# 'us' package provides information about the states and territories of the United States
pip install us
# Out:
# 188.53s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: us in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.1.1)
# Requirement already satisfied: jellyfish==0.11.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from us) (0.11.2)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing the package
import us
# Dictionary to map state abbreviations to full names
state_names = {
    'ak': 'Alaska', 'al': 'Alabama', 'ar': 'Arkansas', 'az': 'Arizona', 'ca': 'California',
    'co': 'Colorado', 'ct': 'Connecticut', 'dc': 'District of Columbia', 'de': 'Delaware', 'fl': 'Florida',
    'ga': 'Georgia', 'hi': 'Hawaii', 'ia': 'Iowa', 'id': 'Idaho', 'il': 'Illinois',
    'in': 'Indiana', 'ks': 'Kansas', 'ky': 'Kentucky', 'la': 'Louisiana', 'ma': 'Massachusetts',
    'md': 'Maryland', 'me': 'Maine', 'mi': 'Michigan', 'mn': 'Minnesota', 'mo': 'Missouri',
    'ms': 'Mississippi', 'mt': 'Montana', 'nc': 'North Carolina', 'nd': 'North Dakota', 'ne': 'Nebraska',
    'nh': 'New Hampshire', 'nj': 'New Jersey', 'nm': 'New Mexico', 'nv': 'Nevada', 'ny': 'New York',
    'oh': 'Ohio', 'ok': 'Oklahoma', 'or': 'Oregon', 'pa': 'Pennsylvania', 'ri': 'Rhode Island',
    'sc': 'South Carolina', 'sd': 'South Dakota', 'tn': 'Tennessee', 'tx': 'Texas', 'ut': 'Utah',
    'va': 'Virginia', 'vt': 'Vermont', 'wa': 'Washington', 'wi': 'Wisconsin', 'wv': 'West Virginia',
    'wy': 'Wyoming'
}

# Rename the rows in the DataFrame
house['state'] = house['state'].replace(state_names)

print(house['state'])
# Out:
# 0         California
# 1         California
# 2         California
# 3         California
# 4         California
#              ...
# 384972    California
# 384973    California
# 384974    California
# 384975    California
# 384976    California
# Name: state, Length: 372501, dtype: object

# %%
# Grouping the DataFrame 'house' by state and calculating the median price for each state
mean_price_state=house.groupby(by=house.state)[['price']].median()
mean_price_state
# Out:
#                        price
# state
# Alabama                850.0
# Alaska                1075.0
# Arizona                990.0
# Arkansas               825.0
# California            1700.0
# Colorado              1427.0
# Connecticut           1286.0
# Delaware              1239.0
# District of Columbia  1725.0
# Florida               1165.0
# Georgia                900.0
# Hawaii                1895.0
# Idaho                 1075.0
# Illinois               825.0
# Indiana                814.0
# Iowa                   870.0
# Kansas                 695.0
# Kentucky               809.0
# Louisiana              876.0
# Maine                 1400.0
# Maryland              1363.0
# Massachusetts         1700.0
# Michigan               945.0
# Minnesota             1140.0
# Mississippi            775.0
# Missouri               700.0
# Montana               1000.0
# Nebraska               930.0
# Nevada                1125.0
# New Hampshire         1610.0
# New Jersey            1646.0
# New Mexico             850.0
# New York              1115.0
# North Carolina         950.0
# North Dakota           925.0
# Ohio                   825.0
# Oklahoma               699.0
# Oregon                1279.0
# Pennsylvania          1150.0
# Rhode Island          1550.0
# South Carolina        1010.0
# South Dakota           800.0
# Tennessee              899.0
# Texas                  905.0
# Utah                  1169.0
# Vermont               1450.0
# Virginia              1149.0
# Washington            1375.0
# West Virginia         1110.0
# Wisconsin              980.0
# Wyoming                824.0

# %%
# Calculate median price by state
mean_price_state = house.groupby(by=house.state)[['price']].median()

# Set figure size
plt.figure(figsize=(20, 10))

# Create bar plot
sns.barplot(x=mean_price_state.index, y=mean_price_state.price, palette='plasma')
# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Set title and labels
plt.title('Exploring Median House Prices Across States', fontsize=18)
plt.xlabel('State', fontsize=16)
plt.ylabel('Median Price', fontsize=16)

# Show plot
plt.show()

# %% [markdown]
# The visualization illustrates the median house prices across different states, revealing insights into regional housing affordability.
# States like Hawaii, California, Distinct of Columbia and  exhibit higher median prices, while others like Ohio, Indiana, and Tennessee tend
# to have lower median prices. This summary aids in understanding the variation in housing costs across states, enabling informed decisions
# for relocation.

# %%
# Define a darker color palette
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# Set the dark grid style
sns.set_style('darkgrid')

# Plot the bar chart with the darker color palette
house['state'].value_counts().plot(kind='bar', figsize=(12, 9), color=colors)

# Set labels and tick format
plt.title('Top States with the Highest Number of Listings', fontsize=18)
plt.xlabel('State', fontsize=14)
plt.ylabel('Listings Count', fontsize=14)
plt.ticklabel_format(axis='y', style='plain')

# Show the plot
plt.show()

# %% [markdown]
# The majority of listings originate from populous states such as California, Florida, and Texas, with North Carolina also featuring
# prominently. This distribution aligns with the expectation that regions with larger populations, like those in California, Texas,
# and Florida, would naturally have more listings, a trend clearly reflected in the data.
